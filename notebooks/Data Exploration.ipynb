for mention in tomatoes_mentions.mentions:
    print(mention)
# Out:
# ft [7,9] lp=0.0053903404623270035
# oct [13,16] lp=0.001804123749025166
# survey [20,26] lp=0.007614289876073599
# uk [34,36] lp=0.10803870856761932
# oper [50,54] lp=0.00855365488678217
# combin [61,67] lp=0.03809523954987526
# region [72,78] lp=0.007102618459612131
# mainland britain [129,145] lp=0.034246575087308884
# britain [138,145] lp=0.0757996216416359
# powergen [150,158] lp=0.3392857015132904
# nation [163,169] lp=0.03732989355921745
# proud [196,201] lp=0.006629714276641607
# boast [202,207] lp=0.005025125574320555
# suppli [222,228] lp=1.0
# will [238,242] lp=0.0036389119923114777
# success [258,265] lp=0.0015522320754826069
# high [284,288] lp=0.0011492393678054214
# still [320,325] lp=0.0010785296326503158
# decad [403,408] lp=0.5714285969734192
# expect [419,425] lp=0.0013986864360049367
# withdraw [429,437] lp=0.0013204672141000628
# next year [449,458] lp=0.00817959662526846
# if [476,478] lp=0.0021620222833007574
# govern [483,489] lp=0.0017703591147437692
# ...

# %%
lunch_annotations = tagme.annotate("941020 ft 20 oct 94 survey of the uk gas market 5 oper to be combin the region electr compani all 14 electr distribut compani on mainland britain and powergen and nation power the generat compani proud boast their own gas suppli arm some will undoubt make a success of them but it is high unlik that all 16 compani will still be involv in what is certain to be a fierc competit market by the end of the decad a few are expect to withdraw within the next year or so particular if the govern delay full competit in gas beyond 1998 few if ani compani are like to lose larg sum of money sinc set up gas trade team often of half a dozen peopl or less has not entail signific invest but compani which withdraw will have to explain whi a diversif that seem too attract to miss two year ago has fail to deliv it promis the initi attract were plain enough the recent regulatori review of the region compani distribut busi underlin the perceiv need from the citi and elsewher for power compani to develop a rang of busi which can make money in competit and therefor unregul market the compani certain have the mean to be abl to diversifi all the region distributor and the generat either have cash surplus or low borrow the problem for them is to do so without arous doubt among investor about whether they are capabl of manag the non power busi they grow or acquir the gas suppli busi has prove a lure becaus of it similar and potenti synergi with electr the region compani have long experi of oper in a low margin trade busi and have develop energi trade expertis which can be use in suppli gas in mani case the custom to whom they sell gas will be the same as those who buy their power electr compani can make use of their brand name and the knowledg they have of the custom to improv their market some have merg their gas and electr sale team bill system can be merg and as technolog develop meter equip can be share there are also synergi with compani generat arm sg warburg secur region electr compani with gas fire generat that is all of them except manweb should be abl to swing between gas generat and gas suppli this it say should reduc the risk of over contract and potenti increas oper margin as a result of season demand kleinwort benson make a similar point about nation power and powergen in a recent research document by develop a gas market busi and a combin heat and power oper which use gas to drive oper a generat has three altern sourc for ani gas it buy includ it own gas fire power station this enabl it select to target it suppli of gas attain the highest margin possibl powergen was one of the first electr compani to enter the competit gas market after set up a joint ventur kinetica with conoco in 1990 in 1993 4 kinetica contribut pound 8m to powergen pre tax profit on sale of pound 130m among the distribut compani midland electr was the first to move into gas market in august 1991 it has a 75 25 joint ventur midland gas with utilicorp and is general consid to be one of the strongest emerg player in the market utilicorp also has joint ventur with norweb scottish power seeboard sweb and eastern northern gas the norweb joint ventur recent announc plan to set up a nation gas market compani total is among other oversea compani involv with region electr compani it has joint ventur with london and yorkshir marathon oil gas has a joint ventur with hydro electr the compani with most commit to gas are those which have gone upstream this summer eastern electr bought a 6 per cent stake in the johnson north sea oil field have previous agre to buy it entir output northern electr the last region electr compani to move into gas suppli creat an upstream gas ventur with nest of finland and has a stake in the victor field yorkshir has 7 per cent of the armada gas field which it bought for pound 27m from amerada hess the aim of those compani move upstream is to develop integr gas busi analyst believ that if the go get tough these compani will be the last to pull out of gas suppli simpli becaus they will have to find other market in which to sell the gas they are produc most believ that the go will get tough kevin lapwood analyst at smith new court say the region electr compani gas busi have not live up to expect when the market first open up it was money for old rope becaus british gas was under pressur to give up market share say mr lapwood but as the market open up further the competit got tougher nobodi is lose much money yet but with margin so thin there are quit a few compani who are unlik to make much sg warburg believ that margin could be as low as 1 per cent when the market is open up fulli this could threaten some region electr compani continu involv in gas given the long wait for deregul of the high margin domest market say analyst nick pink the two main risk say warburg are bad debt and fail to sell all the gas bought from a supplier to an end user that in turn could result in a distress sale")

# Print annotations with a score higher than 0.1
for ann in lunch_annotations.get_annotations(0.5):
    print(ann)
# Out:
# norweb -> NORWEB (score: 0.5801394581794739)
# scottish power -> Scottish Power (score: 0.7271233797073364)
# seeboard -> SEEBOARD (score: 0.8971556425094604)
# sweb -> SWEB Energy (score: 0.5586581826210022)
# norweb -> NORWEB (score: 0.5590020418167114)
# marathon oil -> Marathon Oil (score: 0.7015171647071838)

# %%
import os 
import glob
directory = "../small_data/robust_new/"
query_files = directory + "query_to_docs/*.json" 
files = glob.glob(query_files)
files
relevant_files_directory = "../small_data/robust_new/rel_docs/docs"
relevant_doc_files = glob.glob(relevant_files_directory + "/*")
query_to_relevant_docs = {}
for relevant_doc_file in relevant_doc_files:
    
    query_id = relevant_doc_file.split("/")[-1].split("_")[0].strip()
    document_ids = set()
    for line in open(relevant_doc_file):
        document_ids.add(line.strip())
    query_to_relevant_docs[query_id] = document_ids
# Out:
# 3

# %%
import ast
import json 
hard_query_list = ast.literal_eval(open(os.path.join(directory, "query_MAP.txt")).readline())
hard_query_dict = {}
for hard_query in hard_query_list:
    hard_query_dict[hard_query[0]] = hard_query[1]
    
robust_short_queries_file = open(os.path.join(directory, "robust_short_queries.json"), "w")
robust_short_queries = {}

# There is query_dict with three pieces of information docs, query_text_stemmed, query_text
# query_dict['docs'] will have a list of documents ranked using ql
# each document is a dictionary with four keys doc_text, score, doc_id, rank 
rel = 0
print("Number of files {}".format(len(files)))
import json 
for file in files: 
    query_id = file.split("/")[-1].split(".")[0]
    query_dict = json.load(open(file))
    
    keyword_set_documents = []
    for i in range(1):
        annotated_set = set()
        #text_annotations = tagme.annotate(query_dict['docs'][i]['doc_text'])
        doc_id = query_dict['docs'][i]['doc_id']
#        rel = 0
#        if doc_id in query_to_relevant_docs[query_id]:
#            rel = 1 
#        else:
#            rel = 0
#         for annotation in text_annotations.get_annotations(0.5):
#             print(annotation.begin)
#             print(annotation.end)
#             print(annotation.entity_id)
#             print(annotation.entity_title)
#             print(annotation.score)
#             print(annotation.mention)
            
#             annotated_set.add(annotation.mention)
        keyword_set_documents.append((annotated_set, query_dict['docs'][i]['score'], rel))
        #break
    
    #print(annotated_set)
    #for j in range(len(keyword_set_documents)):
    #    print(keyword_set_documents[j])
    #print("{} {} {}".format(query_id, hard_query_dict[int(query_id)], query_dict["query_text"]))
    robust_short_queries[query_id] = query_dict["query_text"]
    #break
print(len(robust_short_queries))
print(robust_short_queries)
json.dump(robust_short_queries, robust_short_queries_file)
# Out:
# Number of files 250
# 250
# ...

# %%
# Out:
# [(314, 0.0004), (309, 0.0012), (315, 0.0016), (432, 0.0018), (371, 0.0021), (305, 0.0023), (389, 0.0028), (690, 0.0054), (437, 0.0059), (401, 0.0067), (424, 0.0072), (322, 0.0076), (378, 0.0077), (346, 0.0078), (627, 0.0082), (397, 0.0094), (442, 0.0097), (398, 0.0102), (638, 0.0108), (448, 0.0108), (436, 0.0113), (655, 0.0117), (356, 0.0138), (321, 0.0139), (376, 0.0141), (359, 0.0167), (343, 0.0173), (383, 0.0196), (666, 0.0203), (386, 0.0211), (306, 0.0219), (328, 0.0223), (610, 0.0275), (439, 0.0275), (318, 0.0277), (683, 0.0281), (344, 0.0288), (319, 0.0313), (347, 0.0336), (605, 0.0371), (421, 0.0381), (426, 0.0381), (405, 0.039), (435, 0.0394), (449, 0.0403), (662, 0.0412), (651, 0.0422), (608, 0.0433), (352, 0.0465), (391, 0.0468), (689, 0.0491), (402, 0.0492), (301, 0.0502), (381, 0.0515), (320, 0.0516), (670, 0.0531), (325, 0.0549), (440, 0.055), (625, 0.0568), (388, 0.0573), (367, 0.0643), (408, 0.0645), (354, 0.0656), (326, 0.0684), (372, 0.0697), (685, 0.07), (620, 0.072
# ...

# %%
import ast
x = hard_query
x = ast.literal_eval(x)
x
# ['A', 'B', 'C', ' D']
# >>> x = [n.strip() for n in x]
# >>> x
# ['A', 'B', 'C', 'D']
# Out:
# [(314, 0.0004),
#  (309, 0.0012),
#  (315, 0.0016),
#  (432, 0.0018),
#  (371, 0.0021),
#  (305, 0.0023),
#  (389, 0.0028),
#  (690, 0.0054),
#  (437, 0.0059),
#  (401, 0.0067),
#  (424, 0.0072),
#  (322, 0.0076),
#  (378, 0.0077),
#  (346, 0.0078),
#  (627, 0.0082),
#  (397, 0.0094),
#  (442, 0.0097),
#  (398, 0.0102),
#  (638, 0.0108),
#  (448, 0.0108),
#  (436, 0.0113),
#  (655, 0.0117),
#  (356, 0.0138),
#  (321, 0.0139),
#  (376, 0.0141),
#  (359, 0.0167),
#  (343, 0.0173),
#  (383, 0.0196),
#  (666, 0.0203),
#  (386, 0.0211),
#  (306, 0.0219),
#  (328, 0.0223),
#  (610, 0.0275),
#  (439, 0.0275),
#  (318, 0.0277),
#  (683, 0.0281),
#  (344, 0.0288),
#  (319, 0.0313),
#  (347, 0.0336),
#  (605, 0.0371),
#  (421, 0.0381),
#  (426, 0.0381),
#  (405, 0.039),
#  (435, 0.0394),
#  (449, 0.0403),
#  (662, 0.0412),
#  (651, 0.0422),
#  (608, 0.0433),
#  (352, 0.0465),
#  (391, 0.0468),
#  (689, 0.0491),
#  (402, 0.0492),
#  (301, 0.0502),
#  (381, 0.0515),
#  (320, 0.0516),
# ...
